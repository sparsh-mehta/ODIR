# %% [markdown]
# # ENEL 610- Biometric Technologies and Systems
# ## Ocular Disease Intelligent Recognition
# ### Normal v/s Cataract v/s Glaucoma v/s Myopia Prediction

# %% [markdown]
# ### We, request you to use the notebook on google colaboratory platform. Google colaboratory offers free GPU and a lot of libraries needed for machine learning problems are pre-installed on it.
#
# #### This notebook will serve as a step-by-step guide to run the [main](https://colab.research.google.com/drive/1dsFxwebzoSs0Uki68KOG4E5cDQfKKVS4#scrollTo=RydKVFr7l40E) notebook.

# %% [markdown]
# Prerequisite(s):
# 1. Download the *kaggle.json* from [here](https://).

# %% [markdown]
# ### 1) Exploring the dataset, training and testing the models.

# %% [markdown]
# >* Please follow these steps to upload kaggle.json file to download the dataset.
# > 1. Upload the kaggle.json in colab notebook. On the left side of the notebook, you will see an option named *files* please click on that. ![Screenshot (3).png](data:image/png;base64,...)

# %% [markdown]
# > 2. This will let the notebook to automatically connect to the server. Please wait until you see *sample_data* folder. Once, the notebooks connects to the server, please, right click the empty space below *sample_data* and there you will find the option to upload a file. Click upload and direct to the path where we extracted everything and chose *kaggle.json* (See the screenshots)
# ![Screenshot (4).png](data:image/png;base64,...)
# > Redirect to where you saved *kaggle.json*
# ![Screenshot (5).png](data:image/png;base64,...)

# %% [markdown]
# > * Okay, you are good to go. Now either run each cell step-by-step or run all the cells at once by pressing *ctrl + F9*.
# > Note: You will be asked to select a model out of the four models. Please choose a model of your wish! :)

# %% [markdown]
# > * If you wish to run another model just run the cells below the heading *Calling the model* again.
